# %% [markdown]
# # ALAP Scheduling
# ### QFT (4-qubits, 12 CX) + Variational (4-qubits, 16 CX)
#
# 2020-12-13

# %%
# import python tools
import os

# import qiskit tool
from qiskit.transpiler import InstructionDurations

# import experimental tools
from experiments.alap_scheduling import execute_alap, result_alap
from experiments.utils import get_IBM_backend

# %% [markdown]
# ## Experimental Settings

# %%
date = '2020-12-13'

# Choose benchmark circuits from QASMBench
benchmark_sets = ['qft_n4', 'variational_n4']
benchmark_size = 'small'

# %%
# Define backend device
backend = get_IBM_backend('ibmq_paris')
simulator = get_IBM_backend('ibmq_qasm_simulator')

# Number of trials
shots = 8192

# Number of experimental seeds
nseed = 1
# Out:
# /Users/Yasuhiro/.local/share/virtualenvs/experiments-VWP9UmJy/lib/python3.8/site-packages/qiskit/providers/ibmq/ibmqfactory.py:192: UserWarning: Timestamps in IBMQ backend properties, jobs, and job results are all now in local time instead of UTC.
#   warnings.warn('Timestamps in IBMQ backend properties, jobs, and job results '

# %%
# define path to the file to save job data
file_name = date + '_'
sorted_benchmarks = sorted(benchmark_sets)
for _name in sorted_benchmarks: 
    file_name += _name
    if _name == sorted_benchmarks[-1]:
        break
    file_name += '+'
job_save_path = str(os.getcwd()) + "/job_id/from20201211/" + file_name

# %% [markdown]
# ## Execute experiments on IBMQ
#
# Here, we execute three types of experiments. First one is the  job run on simulator to calculate exact answer of the multi-programming circuit. The other two are the jobs executed on the real device. One is the base line, which is no scheduled, and the other one is the circuit executed with alap schedule policy.

# %%
instruction_durations = InstructionDurations.from_backend(backend)

# %%
job_sim, job, job_alap = execute_alap(
                    size=benchmark_size, 
                    names=benchmark_sets, 
                    backend=backend, 
                    simulator=simulator,
                    shots = shots, 
                    nseed=1,
                    save_path=job_save_path, 
                    instruction_durations=instruction_durations,
                    )
# Out:
# prog: Qubit(QuantumRegister(4, 'q15'), 0) , hw: 2
# prog: Qubit(QuantumRegister(4, 'q15'), 1) , hw: 3
# prog: Qubit(QuantumRegister(4, 'q15'), 2) , hw: 1
# prog: Qubit(QuantumRegister(4, 'q15'), 3) , hw: 4
# prog: Qubit(QuantumRegister(4, 'q16'), 0) , hw: 22
# prog: Qubit(QuantumRegister(4, 'q16'), 1) , hw: 19
# prog: Qubit(QuantumRegister(4, 'q16'), 2) , hw: 16
# prog: Qubit(QuantumRegister(4, 'q16'), 3) , hw: 14
# prog: Qubit(QuantumRegister(4, 'q87'), 0) , hw: 2
# prog: Qubit(QuantumRegister(4, 'q87'), 1) , hw: 3
# prog: Qubit(QuantumRegister(4, 'q87'), 2) , hw: 1
# prog: Qubit(QuantumRegister(4, 'q87'), 3) , hw: 4
# prog: Qubit(QuantumRegister(4, 'q88'), 0) , hw: 22
# prog: Qubit(QuantumRegister(4, 'q88'), 1) , hw: 19
# prog: Qubit(QuantumRegister(4, 'q88'), 2) , hw: 16
# prog: Qubit(QuantumRegister(4, 'q88'), 3) , hw: 14

# %%
# Show the each job
print(job_sim)
print(job)
print(job_alap)
# Out:
# <qiskit.providers.ibmq.job.ibmqjob.IBMQJob object at 0x7fc05d52a940>
# [<qiskit.providers.ibmq.job.ibmqjob.IBMQJob object at 0x7fc05e524550>]
# [<qiskit.providers.ibmq.job.ibmqjob.IBMQJob object at 0x7fc05e597dc0>]

# %% [markdown]
# ## Get the results

# %%
# define path to the file to save results
result_save_path = str(os.getcwd()) + "/results/from20201211/" + file_name

# %%
result_sim, result_list, result_alap_list, counts_sim, count_list, counts_alap_list, qc_names = result_alap(backend, simulator, job_save_path, result_save_path)

# %%
# Show the results
print("# Simulator")
print(result_sim)

print("\n# No scheduling")
for _result in result_list: 
    print(_result)

print("\n# ALAP scheduling policy")
for _result_alap in result_alap_list: 
    print(_result_alap)
# Out:
# # Simulator
# Result(backend_name='ibmq_qasm_simulator', backend_version='0.7.0', qobj_id='647e0bb5-626f-41ba-970e-d2d6a4cadc4a', job_id='5fd5bce310ba7c001aa17f24', success=True, results=[ExperimentResult(shots=8192, success=True, meas_level=MeasLevel.CLASSIFIED, data=ExperimentResultData(counts={'0x50': 144, '0x51': 121, '0x52': 134, '0x53': 137, '0x54': 131, '0x55': 130, '0x56': 121, '0x57': 129, '0x58': 130, '0x59': 123, '0x5a': 121, '0x5b': 142, '0x5c': 130, '0x5d': 124, '0x5e': 126, '0x5f': 128, '0x60': 140, '0x61': 124, '0x62': 121, '0x63': 117, '0x64': 120, '0x65': 138, '0x66': 139, '0x67': 119, '0x68': 127, '0x69': 112, '0x6a': 117, '0x6b': 137, '0x6c': 138, '0x6d': 131, '0x6e': 135, '0x6f': 144, '0x90': 113, '0x91': 118, '0x92': 124, '0x93': 137, '0x94': 115, '0x95': 130, '0x96': 148, '0x97': 138, '0x98': 130, '0x99': 111, '0x9a': 132, '0x9b': 112, '0x9c': 140, '0x9d': 118, '0x9e': 123, '0x9f': 135, '0xa0': 119, '0xa1': 128, '0xa2': 131, '0xa3': 118, '0xa4': 143, '0xa5': 118, '0xa6': 147, '0xa7': 116, '0xa8': 134, '0xa9': 137, '0xaa': 106, '0xab': 143, '0xac': 113, '0xad': 137, '0xae': 125, '0xaf': 123}), header=QobjExperimentHeader(clbit_labels=[['c0', 0], ['c0', 1], ['c0', 2], ['c0', 3], ['c1', 0], ['c1', 1], ['c1', 2], ['c1', 3]], creg_sizes=[['c0', 4], ['c1', 4]], global_phase=0.0, memory_slots=8, n_qubits=8, name='circuit8', qreg_sizes=[['q0', 4], ['q1', 4]], qubit_labels=[['q0', 0], ['q0', 1], ['q0', 2], ['q0', 3], ['q1', 0], ['q1', 1], ['q1', 2], ['q1', 3]]), status=DONE, metadata={'fusion': {'applied': False, 'enabled': True, 'method': 'unitary', 'threshold': 14}, 'measure_sampling': True, 'method': 'statevector', 'parallel_shots': 1, 'parallel_state_update': 16}, seed_simulator=1819254997, time_taken=0.054041239000000005)], date=2020-12-13 16:04:08.357555+09:00, status=COMPLETED, status=QobjHeader(backend_name='ibmq_qasm_simulator', backend_version='0.1.547'), metadata={'max_memory_mb': 257936, 'omp_enabled': True, 'parallel_experiments': 1, 'time_taken': 0.054777995}, time_taken=0.054777995, client_version={'qiskit': '0.23.1'})
#
# # No scheduling
# Result(backend_name='ibmq_paris', backend_version='1.6.6', qobj_id='099027fa-557c-4c11-b22f-ea8136de7c9a', job_id='5fd5bce7b98c9b001a5719af', success=True, results=[ExperimentResult(shots=8192, success=True, meas_level=2, data=ExperimentResultData(counts={'0x0':
xe9': 8, '0xea': 2, '0xeb': 3, '0xec': 12, '0xed': 3, '0xee': 9, '0xef': 4, '0xf': 1, '0xf0': 1, '0xf1': 1, '0xf3': 2, '0xf4': 2, '0xf5': 5, '0xf6': 2, '0xfa': 4, '0xfc': 2, '0xfd': 2, '0xfe': 2, '0xff': 4}), header=QobjExperimentHeader(clbit_labels=[['c4', 0], ['c4', 1], ['c4', 2], ['c4', 3], ['c5', 0], ['c5', 1], ['c5', 2], ['c5', 3]], creg_sizes=[['c4', 4], ['c5', 4]], global_phase=0.0, memory_slots=8, n_qubits=27, name='circuit480', qreg_sizes=[['q', 27]], qubit_labels=[['q', 0], ['q', 1], ['q', 2], ['q', 3], ['q', 4], ['q', 5], ['q', 6], ['q', 7], ['q', 8], ['q', 9], ['q', 10], ['q', 11], ['q', 12], ['q', 13], ['q', 14], ['q', 15], ['q', 16], ['q', 17], ['q', 18], ['q', 19], ['q', 20], ['q', 21], ['q', 22], ['q', 23], ['q', 24], ['q', 25], ['q', 26]]), memory=False)], date=2020-12-13 16:39:17+09:00, status=Successful completion, status=QobjHeader(backend_name='ibmq_paris', backend_version='1.6.6'), time_taken=21.784730195999146, execution_id='0a40974c-3d16-11eb-a86c-b02628ea1e00', client_version={'qiskit': '0.23.1'})

# %%
# Show the counts
print("# Simulator")
print(counts_sim)

print("\n# No scheduling")
for _count in count_list: 
    print(_count)

print("\n# ALAP scheduling policy")
for _count_alap in counts_alap_list: 
    print(_count_alap)
# Out:
# # Simulator
# {'0101 0000': 144, '0101 0001': 121, '0101 0010': 134, '0101 0011': 137, '0101 0100': 131, '0101 0101': 130, '0101 0110': 121, '0101 0111': 129, '0101 1000': 130, '0101 1001': 123, '0101 1010': 121, '0101 1011': 142, '0101 1100': 130, '0101 1101': 124, '0101 1110': 126, '0101 1111': 128, '0110 0000': 140, '0110 0001': 124, '0110 0010': 121, '0110 0011': 117, '0110 0100': 120, '0110 0101': 138, '0110 0110': 139, '0110 0111': 119, '0110 1000': 127, '0110 1001': 112, '0110 1010': 117, '0110 1011': 137, '0110 1100': 138, '0110 1101': 131, '0110 1110': 135, '0110 1111': 144, '1001 0000': 113, '1001 0001': 118, '1001 0010': 124, '1001 0011': 137, '1001 0100': 115, '1001 0101': 130, '1001 0110': 148, '1001 0111': 138, '1001 1000': 130, '1001 1001': 111, '1001 1010': 132, '1001 1011': 112, '1001 1100': 140, '1001 1101': 118, '1001 1110': 123, '1001 1111': 135, '1010 0000': 119, '1010 0001': 128, '1010 0010': 131, '1010 0011': 118, '1010 0100': 143, '1010 0101': 118, '1010 0110': 147, '1010 0111': 116, '1010 1000': 134, '1010 1001': 137, '1010 1010': 106, '1010 1011': 143, '1010 1100': 113, '1010 1101': 137, '1010 1110': 125, '1010 1111': 123}
#
# # No scheduling
