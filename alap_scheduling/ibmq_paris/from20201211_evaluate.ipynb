# %% [markdown]
# # Evaluate and Plot ALAP experiments
#
#
# 2020-12-13

# %%
# import python tools
import os
from pprint import pprint

# import experimental tools
from experiments.alap_scheduling import evaluate_alap, plot_alap

# %% [markdown]
# ## Evaluation
# ### Calculate Jensen-Shannon Divergence

# %%
# get current working directory
cwd = str(os.getcwd())

# %%
# define i/o data path
result_dir = cwd + '/results/from20201211/'
save_jsd_path = cwd + '/evaluation/from20201211.pickle'

# %%
# calculate jsd
eval_data = evaluate_alap(result_dir, save_jsd_path)
# Out:
# 11001 1101
# 11001 1110
# 11001 1111
# 11010 0000
# 11010 0001
# 11010 0010
# 11010 0011
# 11010 0100
# 11010 0101
# 11010 0110
# 11010 0111
# 11010 1000
# 11010 1001
# 11010 1010
# 11010 1011
# 11010 1100
# 11010 1101
# 11010 1110
# 11010 1111
# 11011 0000
# 11011 0001
# 11011 0010
# 11011 0011
# 11011 0100
# 11011 0101
# 11011 0110
# 11011 0111
# 11011 1000
# 11011 1001
# 11011 1010
# 11011 1011
# 11011 1100
# 11011 1101
# 11011 1110
# 11011 1111
# 11100 0000
# 11100 0001
# 11100 0010
# 11100 0011
# 11100 0100
# 11100 0101
# 11100 0110
# 11100 0111
# 11100 1000
# 11100 1001
# 11100 1010
# 11100 1011
# 11100 1100
# 11100 1101
# 11100 1110
# 11100 1111
# 11101 0000
# 11101 0001
# 11101 0010
# 11101 0011
# 11101 0100
# 11101 0101
# 11101 0110
# 11101 0111
# 11101 1000
# 11101 1001
# 11101 1010
# 11101 1011
# 11101 1100
# 11101 1101
# 11101 1110
# 11101 1111
# 11110 0000
# 11110 0001
# 11110 0010
# 11110 0011
# 11110 0100
# 11110 0101
# 11110 0110
# 11110 0111
# 11110 1000
# 11110 1001
# 11110 1010
# 11110 1011
# 11110 1100
# 11110 1101
# 11110 1110
# 11110 1111
# 11111 0000
# 11111 0001
# 11111 0010
# 11111 0011
# 11111 0100
# 11111 0101
# 11111 0110
# 11111 0111
# 11111 1000
# 11111 1001
# 11111 1010
# 11111 1011
# 11111 1100
# 11111 1101
# 11111 1110
# 11111 1111
# {'10001 1001': 503, '10010 1001': 516, '10100 1001': 480, '10111 1001': 488, '11000 1001': 501, '11011 1001': 545, '11101 1001': 490, '11110 1001': 498, '00011 1001': 545, '00101 1001': 515, '00110 1001': 498, '00000 1001': 542, '01001 1001': 488, '01010 1001': 490, '01100 1001': 539, '01111 1001': 554}
# 00000 0000
# 00000 0001
# 00000 0010
# 00000 0011
# 00000 0100
# 00000 0101
# 00000 0110
# 00000 0111
# 00000 1000
# 00000 1001
# 00000 1010
# 00000 1011
# 00000 1100
# 00000 1101
# 00000 1110
# 00000 1111
# 00001 0000
# 00001 0001
# 00001 0010
# 00001 0011
# 00001 0100
# 00001 0101
# 00001 0110
# 00001 0111
# 00001 1000
# 00001 1001
# 00001 1010
# 00001 1011
# 00001 1100
# 00001 1101
# 00001 1110
# 00001 1111
# 00010 0000
# 00010 0001
# 00010 0010
# 00010 0011
# 00010 0100
# 00010 0101
# 00010 0110
# 00010 0111
# 00010 1000
# 00010 1001
# 00010 1010
# 00010 1011
# 00010 1100
# 00010 1101
# 00010 1110
# 00010 1111
# 00011 0000
# 00011 0001
# 00011 0010
# 00011 0011
# 00011 0100
# 00011 0101
# 00011 0110
# 00011 0111
# 00011 1000
# 00011 1001
# 00011 1010
# 00011 1011
# 00011 1100
# 00011 1101
# 00011 1110
# 00011 1111
# 00100 0000
# 00100 0001
# 00100 0010
# 00100 0011
# 00100 0100
# 00100 0101
# 00100 0110
# 00100 0111
# 00100 1000
# 00100 1001
# 00100 1010
# 00100 1011
# 00100 1100
# 00100 1101
# 00100 1110
# 00100 1111
# 00101 0000
# 00101 0001
# 00101 0010
# 00101 0011
# 00101 0100
# 00101 0101
# 00101 0110
# 00101 0111
# 00101 1000
# 00101 1001
# 00101 1010
# 00101 1011
# 00101 1100
# 00101 1101
# 00101 1110
# 00101 1111
# 00110 0000
# 00110 0001
# 00110 0010
# 00110 0011
# 00110 0100
# 00110 0101
# 00110 0110
# 00110 0111
# 00110 1000
# 00110 1001
# 00110 1010
# 00110 1011
# 00110 1100
# 00110 1101
# 00110 1110
# 00110 1111
# 00111 0000
# 00111 0001
# 00111 0010
# 00111 0011
# 00111 0100
# 00111 0101
# 00111 0110
# 00111 0111
# 00111 1000
# 00111 1001
# 00111 1010
# 00111 1011
# 00111 1100
# 00111 1101
# 00111 1110
# 00111 1111
# 01000 0000
# 01000 0001
# 01000 0010
# 01000 0011
# 01000 0100
# 01000 0101
# 01000 0110
# 01000 0111
# 01000 1000
# 01000 1001
# 01000 1010
# 01000 1011
# 01000 1100
# 01000 1101
# 01000 1110
# 01000 1111
# 01001 0000
# 01001 0001
# 01001 0010
# 01001 0011
# 01001 0100
# 01001 0101
# 01001 0110
# 01001 0111
# 01001 1000
# 01001 1001
# 01001 1010
# 01001 1011
# 01001 1100
# 01001 1101
# 01001 1110
# 01001 1111
# 01010 0000
# 01010 0001
# 01010 0010
# 01010 0011
# 01010 0100
# 01010 0101
# 01010 0110
# 01010 0111
# 01010 1000
# 01010 1001
# 01010 1010
# 01010 1011
# 01010 1100
# 01010 1101
# 01010 1110
# 01010 1111
# 01011 0000
# 01011 0001
# 01011 0010
# 01011 0011
# 01011 0100
# 01011 0101
# 01011 0110
# 01011 0111
# 01011 1000
# 01011 1001
# 01011 1010
# 01011 1011
# 01011 1100
# 01011 1101
# 01011 1110
# 01011 1111
# 01100 0000
# 01100 0001
# 01100 0010
# 01100 0011
# 01100 0100
# 01100 0101
# 01100 0110
# 01100 0111
# 01100 1000
# 01100 1001
# 01100 1010
# 01100 1011
# 01100 1100
# 01100 1101
# 01100 1110
# 01100 1111
# 01101 0000
# 01101 0001
# 01101 0010
# 01101 0011
# 01101 0100
# 01101 0101
# 01101 0110
# 01101 0111
# 01101 1000
# 01101 1001
# 01101 1010
# 01101 1011
# 01101 1100
# 01101 1101
# 01101 1110
# 01101 1111
# 01110 0000
# 01110 0001
# 01110 0010
# 01110 0011
# 01110 0100
# 01110 0101
# 01110 0110
# 01110 0111
# 01110 1000
# 01110 1001
# 01110 1010
# 01110 1011
# 01110 1100
# 01110 1101
# 01110 1110
# 01110 1111
# 01111 0000
# 01111 0001
# 01111 0010
# 01111 0011
# 01111 0100
# 01111 0101
# 01111 0110
# 01111 0111
# 01111 1000
# 01111 1001
# 01111 1010
# 01111 1011
# 01111 1100
# 01111 1101
# 01111 1110
# 01111 1111
# 10000 0000
# 10000 0001
# 10000 0010
# 10000 0011
# 10000 0100
# 10000 0101
# 10000 0110
# 10000 0111
# 10000 1000
# 10000 1001
# 10000 1010
# 10000 1011
# 10000 1100
# 10000 1101
# 10000 1110
# 10000 1111
# 10001 0000
# 10001 0001
# 10001 0010
# 10001 0011
# 10001 0100
# 10001 0101
# 10001 0110
# 10001 0111
# 10001 1000
# 10001 1001
# 10001 1010
# 10001 1011
# 10001 1100
# 10001 1101
# 10001 1110
# 10001 1111
# 10010 0000
# 10010 0001
# 10010 0010
# 10010 0011
# 10010 0100
# 10010 0101
# 10010 0110
# 10010 0111
# 10010 1000
# 10010 1001
# 10010 1010
# 10010 1011
# 10010 1100
# 10010 1101
# 10010 1110
# 10010 1111
# 10011 0000
# 10011 0001
# 10011 0010
# 10011 0011
# 10011 0100
# 10011 0101
# 10011 0110
# 10011 0111
# 10011 1000
# 10011 1001
# 10011 1010
# 10011 1011
# 10011 1100
# 10011 1101
# 10011 1110
# 10011 1111
# 10100 0000
# 10100 0001
# 10100 0010
# 10100 0011
# 10100 0100
# 10100 0101
# 10100 0110
# 10100 0111
# 10100 1000
# 10100 1001
# 10100 1010
# 10100 1011
# 10100 1100
# 10100 1101
# 10100 1110
# 10100 1111
# 10101 0000
# 10101 0001
# 10101 0010
# 10101 0011
# 10101 0100
# 10101 0101
# 10101 0110
# 10101 0111
# 10101 1000
# 10101 1001
# 10101 1010
# 10101 1011
# 10101 1100
# 10101 1101
# 10101 1110
# 10101 1111
# 10110 0000
# 10110 0001
# 10110 0010
# 10110 0011
# 10110 0100
# 10110 0101
# 10110 0110
# 10110 0111
# 10110 1000
# 10110 1001
# 10110 1010
# 10110 1011
# 10110 1100
# 10110 1101
# 10110 1110
# 10110 1111
# 10111 0000
# 10111 0001
# 10111 0010
# 10111 0011
# 10111 0100
# 10111 0101
# 10111 0110
# 10111 0111
# 10111 1000
# 10111 1001
# 10111 1010
# 10111 1011
# 10111 1100
# 10111 1101
# 10111 1110
# 10111 1111
# 11000 0000
# 11000 0001
# 11000 0010
# 11000 0011
# 11000 0100
# 11000 0101
# 11000 0110
# 11000 0111
# 11000 1000
# 11000 1001
# 11000 1010
# 11000 1011
# 11000 1100
# 11000 1101
# 11000 1110
# 11000 1111
# 11001 0000
# 11001 0001
# 11001 0010
# 11001 0011
# 11001 0100
# 11001 0101
# 11001 0110
# 11001 0111
# 11001 1000
# 11001 1001
# 11001 1010
# 11001 1011
# 11001 1100
# 11001 1101
# 11001 1110
# 11001 1111
# 11010 0000
# 11010 0001
# 11010 0010
# 11010 0011
# 11010 0100
# 11010 0101
# 11010 0110
# 11010 0111
# 11010 1000
# 11010 1001
# 11010 1010
# 11010 1011
# 11010 1100
# 11010 1101
# 11010 1110
# 11010 1111
# 11011 0000
# 11011 0001
# 11011 0010
# 11011 0011
# 11011 0100
# 11011 0101
# 11011 0110
# 11011 0111
# 11011 1000
# 11011 1001
# 11011 1010
# 11011 1011
# 11011 1100
# 11011 1101
# 11011 1110
# 11011 1111
# 11100 0000
# 11100 0001
# 11100 0010
# 11100 0011
# 11100 0100
# 11100 0101
# 11100 0110
# 11100 0111
# 11100 1000
# 11100 1001
# 11100 1010
# 11100 1011
# 11100 1100
# 11100 1101
# 11100 1110
# 11100 1111
# 11101 0000
# 11101 0001
# 11101 0010
# 11101 0011
# 11101 0100
# 11101 0101
# 11101 0110
# 11101 0111
# 11101 1000
# 11101 1001
# 11101 1010
# 11101 1011
# 11101 1100
# 11101 1101
# 11101 1110
# 11101 1111
# 11110 0000
# 11110 0001
# 11110 0010
# 11110 0011
# 11110 0100
# 11110 0101
# 11110 0110
# 11110 0111
# 11110 1000
# 11110 1001
# 11110 1010
# 11110 1011
# 11110 1100
# 11110 1101
# 11110 1110
# 11110 1111
# 11111 0000
# 11111 0001
# 11111 0010
# 11111 0011
# 11111 0100
# 11111 0101
# 11111 0110
# 11111 0111
# 11111 1000
# 11111 1001
# 11111 1010
# 11111 1011
# 11111 1100
# 11111 1101
# 11111 1110
# 11111 1111
# {'00000 0000': 29, '00000 0001': 47, '00001 0000': 9, '10000 0000': 28, '10000 0001': 51, '10000 0011': 2, '10000 0100': 8, '10000 0101': 7, '10000 0110': 10, '10000 0111': 7, '10000 1000': 29, '10000 1001': 303, '10000 1011': 6, '10000 1100': 11, '10000 1101': 18, '10000 1110': 1, '10000 1111': 1, '00001 0001': 16, '10001 0000': 18, '10001 0001': 35, '10001 0010': 1, '10001 0100': 2, '10001 0101': 20, '10001 0110': 9, '10001 0111': 5, '10001 1000': 37, '10001 1001': 257, '10001 1010': 1, '10001 1011': 4, '10001 1100': 6, '10001 1101': 11, '10001 1111': 2, '00001 0010': 1, '10010 0000': 9, '10010 0001': 23, '10010 0010': 1, '10010 0011': 1, '10010 0100': 5, '10010 0101': 6, '10010 0110': 3, '10010 0111': 2, '10010 1000': 17, '10010 1001': 181, '10010 1011': 2, '10010 1100': 2, '10010 1101': 12, '10010 1110': 1, '10011 0000': 6, '10011 0001': 18, '10011 0100': 2, '10011 0101': 4, '10011 0111': 2, '10011 1000': 10, '10011 1001': 103, '10011 1010': 1, '10011 1011': 1, '10011 1100': 2, '10011 1101': 2, '00001 0100': 2, '10100 0000': 27, '10100 0001': 37, '10100 0010': 3, '10100 0011': 4, '10100 0100': 5, '10100 0101': 12, '10100 0110': 8, '10100 0111': 5, '10100 1000': 15, '10100 1001': 273, '10100 1010': 2, '10100 1011': 4, '10100 1100': 4, '10100 1101': 15, '10100 1111': 3, '00001 0101': 5, '10101 0000': 8, '10101 0001': 19, '10101 0010': 2, '10101 0100': 2, '10101 0101': 5, '10101 0110': 3, '10101 0111': 2, '10101 1000': 9, '10101 1001': 141, '10101 1011': 1, '10101 1100': 2, '10101 1101': 10, '00001 0110': 4, '10110 0000': 17, '10110 0001': 22, '10110 0011': 1, '10110 0100': 7, '10110 0101': 5, '10110 0110': 9, '10110 0111': 3, '10110 1000': 22, '10110 1001': 219, '10110 1010': 2, '10110 1011': 1, '10110 1100': 6, '10110 1101': 6, '10110 1110': 1, '10111 0000': 8, '10111 0001': 17, '10111 0011': 1, '10111 0101': 2, '10111 0110': 1, '10111 0111': 2, '10111 1000': 5, '10111 1001': 143, '10111 1010': 2, '10111 1011': 2, '10111 1100': 2, '10111 1101': 5, '10111 1110': 1, '10111 1111': 1, '00001 1000': 14, '11000 0000': 15, '11000 0001': 28, '11000 0011': 1, '11000 0100': 5, '11000 0101': 5, '11000 0110': 2, '11000 0111': 3, '11000 1000': 13, '11000 1001': 202, '11000 1011': 2, '11000 1100': 2, '11000 1101': 5, '11000 1110': 1, '00001 1001': 154, '11001 0000': 6, '11001 0001': 10, '11001 0011': 1, '11001 0100': 1, '11001 0101': 3, '11001 0110': 3, '11001 0111': 4, '11001 1000': 6, '11001 1001': 115, '11001 1100': 2, '11001 1101': 2, '11010 0000': 9, '11010 0001': 25, '11010 0011': 3, '11010 0100': 3, '11010 0101': 5, '11010 0110': 4, '11010 0111': 2, '11010 1000': 11, '11010 1001': 141, '11010 1011': 2, '11010 1100': 2, '11010 1101': 8, '11010 1110': 1, '11010 1111': 1, '00001 1011': 1, '11011 0000': 9, '11011 0001': 9, '11011 0101': 1, '11011 0110': 1, '11011 0111': 2, '11011 1000': 4, '11011 1001': 108, '11011 1010': 1, '11011 1011': 3, '11011 1100': 1, '11011 1101': 6, '11011 1111': 2, '00001 1100': 3, '11100 0000': 14, '11100 0001': 38, '11100 0010': 1, '11100 0011': 1, '11100 0100': 5, '11100 0101': 4, '11100 0110': 3, '11100 0111': 4, '11100 1000': 16, '11100 1001': 185, '11100 1011': 2, '11100 1100': 3, '11100 1101': 11, '00001 1101': 6, '11101 0000': 7, '11101 0001': 15, '11101 0010': 1, '11101 0011': 1, '11101 0100': 2, '11101 0101': 4, '11101 0110': 1, '11101 1000': 12, '11101 1001': 136, '11101 1010': 1, '11101 1011': 1, '11101 1100': 3, '11101 1101': 13, '11101 1110': 1, '11101 1111': 2, '11110 0000': 3, '11110 0001': 19, '11110 0011': 2, '11110 0100': 1, '11110 0101': 4, '11110 0110': 2, '11110 0111': 3, '11110 1000': 15, '11110 1001': 157, '11110 1010': 3, '11110 1101': 9, '11110 1110': 3, '00001 1111': 1, '11111 0000': 5, '11111 0001': 9, '11111 0100': 1, '11111 0101': 4, '11111 0110': 4, '11111 1000': 4, '11111 1001': 67, '11111 1010': 1, '11111 1011': 1, '11111 1100': 1, '11111 1101': 6, '00000 0010': 2, '00010 0000': 16, '00010 0001': 27, '00010 0010': 3, '00010 0011': 1, '00010 0100': 5, '00010 0101': 6, '00010 0 ...
# 00000 0000
# 00000 0001
# 00000 0010
# 00000 0011
# 00000 0100
# 00000 0101
# 00000 0110
# 00000 0111
# 00000 1000
# 00000 1001
# 00000 1010
# 00000 1011
# 00000 1100
# 00000 1101
# 00000 1110
# 00000 1111
# 00001 0000
# 00001 0001
# 00001 0010
# 00001 0011
# 00001 0100
# 00001 0101
# 00001 0110
# 00001 0111
# 00001 1000
# 00001 1001
# 00001 1010
# 00001 1011
# 00001 1100
# 00001 1101
# 00001 1110
# 00001 1111
# 00010 0000
# 00010 0001
# 00010 0010
# 00010 0011
# 00010 0100
# 00010 0101
# 00010 0110
# 00010 0111
# 00010 1000
# 00010 1001
# 00010 1010
# 00010 1011
# 00010 1100
# 00010 1101
# 00010 1110
# 00010 1111
# 00011 0000
# 00011 0001
# 00011 0010
# 00011 0011
# 00011 0100
# 00011 0101
# 00011 0110
# 00011 0111
# 00011 1000
# 00011 1001
# 00011 1010
# 00011 1011
# 00011 1100
# 00011 1101
# 00011 1110
# 00011 1111
# 00100 0000
# 00100 0001
# 00100 0010
# 00100 0011
# 00100 0100
# 00100 0101
# 00100 0110
# 00100 0111
# 00100 1000
# 00100 1001
# 00100 1010
# 00100 1011
# 00100 1100
# 00100 1101
# 00100 1110
# 00100 1111
# 00101 0000
# 00101 0001
# 00101 0010
# 00101 0011
# 00101 0100
# 00101 0101
# 00101 0110
# 00101 0111
# 00101 1000
# 00101 1001
# 00101 1010
# 00101 1011
# 00101 1100
# 00101 1101
# 00101 1110
# 00101 1111
# 00110 0000
# 00110 0001
# 00110 0010
# 00110 0011
# 00110 0100
# 00110 0101
# 00110 0110
# 00110 0111
# 00110 1000
# 00110 1001
# 00110 1010
# 00110 1011
# 00110 1100
# 00110 1101
# 00110 1110
# 00110 1111
# 00111 0000
# 00111 0001
# 00111 0010
# 00111 0011
# 00111 0100
# 00111 0101
# 00111 0110
# 00111 0111
# 00111 1000
# 00111 1001
# 00111 1010
# 00111 1011
# 00111 1100
# 00111 1101
# 00111 1110
# 00111 1111
# 01000 0000
# 01000 0001
# 01000 0010
# 01000 0011
# 01000 0100
# 01000 0101
# 01000 0110
# 01000 0111
# 01000 1000
# 01000 1001
# 01000 1010
# 01000 1011
# 01000 1100
# 01000 1101
# 01000 1110
# 01000 1111
# 01001 0000
# 01001 0001
# 01001 0010
# 01001 0011
# 01001 0100
# 01001 0101
# 01001 0110
# 01001 0111
# 01001 1000
# 01001 1001
# 01001 1010
# 01001 1011
# 01001 1100
# 01001 1101
# 01001 1110
# 01001 1111
# 01010 0000
# 01010 0001
# 01010 0010
# 01010 0011
# 01010 0100
# 01010 0101
# 01010 0110
# 01010 0111
# 01010 1000
# 01010 1001
# 01010 1010
# 01010 1011
# 01010 1100
# 01010 1101
# 01010 1110
# 01010 1111
# 01011 0000
# 01011 0001
# 01011 0010
# 01011 0011
# 01011 0100
# 01011 0101
# 01011 0110
# 01011 0111
# 01011 1000
# 01011 1001
# 01011 1010
# 01011 1011
# 01011 1100
# 01011 1101
# 01011 1110
# 01011 1111
# 01100 0000
# 01100 0001
# 01100 0010
# 01100 0011
# 01100 0100
# 01100 0101
# 01100 0110
# 01100 0111
# 01100 1000
# 01100 1001
# 01100 1010
# 01100 1011
# 01100 1100
# 01100 1101
# 01100 1110
# 01100 1111
# 01101 0000
# 01101 0001
# 01101 0010
# 01101 0011
# 01101 0100
# 01101 0101
# 01101 0110
# 01101 0111
# 01101 1000
# 01101 1001
# 01101 1010
# 01101 1011
# 01101 1100
# 01101 1101
# 01101 1110
# 01101 1111
# 01110 0000
# 01110 0001
# 01110 0010
# 01110 0011
# 01110 0100
# 01110 0101
# 01110 0110
# 01110 0111
# 01110 1000
# 01110 1001
# 01110 1010
# 01110 1011
# 01110 1100
# 01110 1101
# 01110 1110
# 01110 1111
# 01111 0000
# 01111 0001
# 01111 0010
# 01111 0011
# 01111 0100
# 01111 0101
# 01111 0110
# 01111 0111
# 01111 1000
# 01111 1001
# 01111 1010
# 01111 1011
# 01111 1100
# 01111 1101
# 01111 1110
# 01111 1111
# 10000 0000
# 10000 0001
# 10000 0010
# 10000 0011
# 10000 0100
# 10000 0101
# 10000 0110
# 10000 0111
# 10000 1000
# 10000 1001
# 10000 1010
# 10000 1011
# 10000 1100
# 10000 1101
# 10000 1110
# 10000 1111
# 10001 0000
# 10001 0001
# 10001 0010
# 10001 0011
# 10001 0100
# 10001 0101
# 10001 0110
# 10001 0111
# 10001 1000
# 10001 1001
# 10001 1010
# 10001 1011
# 10001 1100
# 10001 1101
# 10001 1110
# 10001 1111
# 10010 0000
# 10010 0001
# 10010 0010
# 10010 0011
# 10010 0100
# 10010 0101
# 10010 0110
# 10010 0111
# 10010 1000
# 10010 1001
# 10010 1010
# 10010 1011
# 10010 1100
# 10010 1101
# 10010 1110
# 10010 1111
# 10011 0000
# 10011 0001
# 10011 0010
# 10011 0011
# 10011 0100
# 10011 0101
# 10011 0110
# 10011 0111
# 10011 1000
# 10011 1001
# 10011 1010
# 10011 1011
# 10011 1100
# 10011 1101
# 10011 1110
# 10011 1111
# 10100 0000
# 10100 0001
# 10100 0010
# 10100 0011
# 10100 0100
# 10100 0101
# 10100 0110
# 10100 0111
# 10100 1000
# 10100 1001
# 10100 1010
# 10100 1011
# 10100 1100
# 10100 1101
# 10100 1110
# 10100 1111
# 10101 0000
# 10101 0001
# 10101 0010
# 10101 0011
# 10101 0100
# 10101 0101
# 10101 0110
# 10101 0111
# 10101 1000
# 10101 1001
# 10101 1010
# 10101 1011
# 10101 1100
# 10101 1101
# 10101 1110
# 10101 1111
# 10110 0000
# 10110 0001
# 10110 0010
# 10110 0011
# 10110 0100
# 10110 0101
# 10110 0110
# 10110 0111
# 10110 1000
# 10110 1001
# 10110 1010
# 10110 1011
# 10110 1100
# 10110 1101
# 10110 1110
# 10110 1111
# 10111 0000
# 10111 0001
# 10111 0010
# 10111 0011
# 10111 0100
# 10111 0101
# 10111 0110
# 10111 0111
# 10111 1000
# 10111 1001
# 10111 1010
# 10111 1011
# 10111 1100
# 10111 1101
# 10111 1110
# 10111 1111
# 11000 0000
# 11000 0001
# 11000 0010
# 11000 0011
# 11000 0100
# 11000 0101
# 11000 0110
# 11000 0111
# 11000 1000
# 11000 1001
# 11000 1010
# 11000 1011
# 11000 1100
# 11000 1101
# 11000 1110
# 11000 1111
# 11001 0000
# 11001 0001
# 11001 0010
# 11001 0011
# 11001 0100
# 11001 0101
# 11001 0110
# 11001 0111
# 11001 1000
# 11001 1001
# 11001 1010
# 11001 1011
# 11001 1100
# 11001 1101
# 11001 1110
# 11001 1111
# 11010 0000
# 11010 0001
# 11010 0010
# 11010 0011
# 11010 0100
# 11010 0101
# 11010 0110
# 11010 0111
# 11010 1000
# 11010 1001
# 11010 1010
# 11010 1011
# 11010 1100
# 11010 1101
# 11010 1110
# 11010 1111
# 11011 0000
# 11011 0001
# 11011 0010
# 11011 0011
# 11011 0100
# 11011 0101
# 11011 0110
# 11011 0111
# 11011 1000
# 11011 1001
# 11011 1010
# 11011 1011
# 11011 1100
# 11011 1101
# 11011 1110
# 11011 1111
# 11100 0000
# 11100 0001
# 11100 0010
# 11100 0011
# 11100 0100
# 11100 0101
# 11100 0110
# 11100 0111
# 11100 1000
# 11100 1001
# 11100 1010
# 11100 1011
# 11100 1100
# 11100 1101
# 11100 1110
# 11100 1111
# 11101 0000
# 11101 0001
# 11101 0010
# 11101 0011
# 11101 0100
# 11101 0101
# 11101 0110
# 11101 0111
# 11101 1000
# 11101 1001
# 11101 1010
# 11101 1011
# 11101 1100
# 11101 1101
# 11101 1110
# 11101 1111
# 11110 0000
# 11110 0001
# 11110 0010
# 11110 0011
# 11110 0100
# 11110 0101
# 11110 0110
# 11110 0111
# 11110 1000
# 11110 1001
# 11110 1010
# 11110 1011
# 11110 1100
# 11110 1101
# 11110 1110
# 11110 1111
# 11111 0000
# 11111 0001
# 11111 0010
# 11111 0011
# 11111 0100
# 11111 0101
# 11111 0110
# 11111 0111
# 11111 1000
# 11111 1001
# 11111 1010
# 11111 1011
# 11111 1100
# 11111 1101
# 11111 1110
# 11111 1111

# %%
# show the data
pprint(eval_data)
# Out:
# {'adder_n4 + basis_change_n3': {'alap': {'mean': 0.4540281360798795, 'sem': 0},
#                                 'non_scheduling': {'mean': 0.464284866337125,
#                                                    'sem': 0}},
#  'adder_n4 + deutsch_n2': {'alap': {'mean': 0.39006720768974373, 'sem': 0},
#                            'non_scheduling': {'mean': 0.39462830123282067,
#                                               'sem': 0}},
#  'adder_n4 + error_correctiond3_n5': {'alap': {'mean': 0.5536985029109958,
#                                                'sem': 0},
#                                       'non_scheduling': {'mean': 0.5808158554603082,
#                                                          'sem': 0}},
#  'adder_n4 + fredkin_n3': {'alap': {'mean': 0.5072669094742878, 'sem': 0},
#                            'non_scheduling': {'mean': 0.5133643377398165,
#                                               'sem': 0}},
#  'basis_change_n3 + cat_state_n4': {'alap': {'mean': 0.3728995344649619,
#                                              'sem': 0},
#                                     'non_scheduling': {'mean': 0.364741602955483,
#                                                        'sem': 0}},
#  'basis_change_n3 + deutsch_n2': {'alap': {'mean': 0.3928184606058749,
#                                            'sem': 0},
#                                   'non_scheduling': {'mean': 0.3924219849852771,
#                                                      'sem': 0}},
#  'basis_change_n3 + error_correctiond3_n5': {'alap': {'mean': 0.5403164060035386,
#                                                       'sem': 0},
#                                              'non_scheduling': {'mean': 0.5381508953782794,
#                                                                 'sem': 0}},
#  'basis_change_n3 + qft_n4': {'alap': {'mean': 0.25759412492976913, 'sem': 0},
#                               'non_scheduling': {'mean': 0.25213772792787575,
#                                                  'sem': 0}},
#  'basis_change_n3 + variational_n4': {'alap': {'mean': 0.3462253811039498,
#                                                'sem': 0},
#                                       'non_scheduling': {'mean': 0.33949125135606073,
#                                                          'sem': 0}},
#  'basis_change_n3 + vqe_uccsd_n4': {'alap': {'mean': 0.5550064899082602,
#                                              'sem': 0},
#                                     'non_scheduling': {'mean': 0.5589759170202379,
#                                                        'sem': 0}},
#  'cat_state_n4 + deutsch_n2': {'alap': {'mean': 0.2690691402698023, 'sem': 0},
#                                'non_scheduling': {'mean': 0.2672489067057634,
#                                                   'sem': 0}},
#  'cat_state_n4 + error_correctiond3_n5': {'alap': {'mean': 0.5146324474419536,
#                                                    'sem': 0},
#                                           'non_scheduling': {'mean': 0.49892464042839507,
#                                                              'sem': 0}},
#  'cat_state_n4 + fredkin_n3': {'alap': {'mean': 0.3773350522186001, 'sem': 0},
#                                'non_scheduling': {'mean': 0.39968371669744723,
#                                                   'sem': 0}},
#  'cat_state_n4 + grover_n2': {'alap': {'mean': 0.32582203636017204, 'sem': 0},
#                               'non_scheduling': {'mean': 0.32777961847456705,
#                                                  'sem': 0}},
#  'deutsch_n2 + error_correctiond3_n5': {'alap': {'mean': 0.4676154410122547,
#                                                  'sem': 0},
#                                         'non_scheduling': {'mean': 0.4859929343253395,
#                                                            'sem': 0}},
#  'deutsch_n2 + fredkin_n3': {'alap': {'mean': 0.34364552166877493, 'sem': 0},
#                              'non_scheduling': {'mean': 0.3411146645061082,
#                                                 'sem': 0}},
#  'deutsch_n2 + qft_n4': {'alap': {'mean': 0.19794047739593962, 'sem': 0},
#                          'non_scheduling': {'mean': 0.139893131633302,
#                                             'sem': 0}},
#  'error_correctiond3_n5 + fredkin_n3': {'alap': {'mean': 0.5792200987412411,
#                                                  'sem': 0},
#                                         'non_scheduling': {'mean': 0.579197888975812,
#                                                            'sem': 0}},
#  'error_correctiond3_n5 + grover_n2': {'alap': {'mean': 0.48372676626328975,
#                                                 'sem': 0},
#                                        'non_scheduling': {'mean': 0.47500643201904924,
#                                                           'sem': 0}},
#  'error_correctiond3_n5 + qft_n4': {'alap': {'mean': 0.4820499157679556,
#                                              'sem': 0},
#                                     'non_scheduling': {'mean': 0.48208828031417184,
#                                                        'sem': 0}},
#  'error_correctiond3_n5 + variational_n4': {'alap': {'mean': 0.5251002698042917,
#                                                      'sem': 0},
#                                             'non_scheduling': {'mean': 0.5910255208107875,
#                                                                'sem': 0}},
#  'error_correctiond3_n5 + vqe_uccsd_n4': {'alap': {'mean': 0.6354941947558881,
#                                                    'sem': 0},
#                                           'non_scheduling': {'mean': 0.6390982939248633,
#                                                              'sem': 0}},
#  'fredkin_n3 + grover_n2': {'alap': {'mean': 0.33357410869411047, 'sem': 0},
#                             'non_scheduling': {'mean': 0.30961465520699877,
#                                                'sem': 0}},
#  'fredkin_n3 + qft_n4': {'alap': {'mean': 0.2608619397638355, 'sem': 0},
#                          'non_scheduling': {'mean': 0.2603705517483284,
#                                             'sem': 0}},
#  'fredkin_n3 + variational_n4': {'alap': {'mean': 0.4224738321922238, 'sem': 0},
#                                  'non_scheduling': {'mean': 0.4124972278385984,
#                                                     'sem': 0}},
#  'grover_n2 + qft_n4': {'alap': {'mean': 0.1847640129742787, 'sem': 0},
#                         'non_scheduling': {'mean': 0.1783428474879666,
#                                            'sem': 0}},
#  'grover_n2 + toffoli_n3': {'alap': {'mean': 0.342884053618249, 'sem': 0},
#                             'non_scheduling': {'mean': 0.33653255948706884,
#                                                'sem': 0}}}

# %% [markdown]
# ## Plot data

# %%
# define image save path
save_plot_path = cwd + '/plot/from20201211.png'

# %%
# make plot and save
plot_alap(save_jsd_path, save_plot_path=save_plot_path)
